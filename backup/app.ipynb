# %%
# Se o site estiver instável, usar dados locais (CSV/JSON pré-baixados).
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def scrape_embrapa(ano: int, opcao: str, subopcao: str = None):
    url = f"http://vitibrasil.cnpuv.embrapa.br/index.php?ano={ano}&opcao={opcao}"
    if subopcao:
        url += f"&subopcao={subopcao}"
    
    try:
        response = requests.get(url, timeout=10)
        soup = BeautifulSoup(response.text, 'html.parser')
        tabela = soup.find("table", {"class": "tb_base tb_dados"}) 
        linhas = tabela.find_all("tr")

        # Pegar cabeçalhos da primeira linha
        cabecalhos_linha = linhas[0].find_all("th")
        cabecalhos = [th.get_text(strip=True) for th in cabecalhos_linha]

        # Verificar número de colunas pelos cabeçalhos
        num_colunas = len(cabecalhos)

        # Criar dicionário apropriado baseado no número de colunas
        resultado = {}

        # Itera sobre as linhas para extrair os dados
        for linha in linhas[1:]:
            celulas = linha.find_all("td")
            if celulas:  # Ignora linhas sem células
                valores = [td.get_text(strip=True) for td in celulas]
                
                # Trata o caso de 2 colunas (Produto/Quantidade)
                if num_colunas == 2:
                    # Usa a primeira coluna como chave e a segunda como valor
                    if len(valores) >= 2:
                        resultado[valores[0]] = valores[1]
                
                # Trata o caso de 3 colunas (País/Quantidade/Valor)
                elif num_colunas == 3:
                    # Usa a primeira coluna como chave e cria um sub-dicionário para as outras colunas
                    if len(valores) >= 3:
                        resultado[valores[0]] = {
                            cabecalhos[1]: valores[1],
                            cabecalhos[2]: valores[2]
                        }
        
        return resultado
    
    except Exception as e:
        print(f"Erro ao fazer scraping: {e}")
        return {}

# %%
# PRODUTO opcao="opt_02"
scrape_embrapa(ano=2020, opcao="opt_02")
# Out:
# {'VINHO DE MESA': '124.200.414',
#  'Tinto': '15.451.883',
#  'Branco': '15.487.915',
#  'Rosado': '1.576.888',
#  'VINHO FINO DE MESA (VINIFERA)': '32.516.686',
#  'SUCO': '69.261.287',
#  'Suco de uva integral': '40.718.523',
#  'Suco de uva concentrado': '27.963.865',
#  'Suco de uva adoçado': '107.289',
#  'Suco de uva orgânico': '471.610',
#  'Suco de uva reconstituído': '-',
#  'DERIVADOS': '92.533.804',
#  'Espumante': '32.399',
#  'Espumante moscatel': '689.139',
#  'Base espumante': '-',
#  'Base espumante moscatel': '3.006.705',
#  'Base Champenoise champanha': '200.777',
#  'Base Charmat champanha': '2.487.939',
#  'Bebida de uva': '-',
#  'Polpa de uva': '1.803.472',
#  'Mosto simples': '80.355.474',
#  'Mosto concentrado': '-',
#  'Mosto de uva com bagaço': '3.078.256',
#  'Mosto dessulfitado': '5.000',
#  'Mistelas': '-',
#  'Néctar de uva': '46.000',
#  'Licorosos': '-',
#  'Compostos': '-',
#  'Jeropiga': '2.000',
#  'Filtrado': '-',
#  'Frisante': '-',
#  'Vinho leve': '-',
#  'Vinho licoroso': '48.678',
#  'Brandy': '-',
#  'Destilado': '-',
#  'Bagaceira': '-',
#  'Licor de bagaceira': '5.800',
#  'Vinagre': '10.000',
#  'Borra líquida': '509.378',
#  'Borra seca': '167.587',
#  'Vinho Composto': '-',
#  'Pisco': '1.000',
#  'Vinho orgânico': '18.700',
#  'Espumante orgânico': '-',
#  'Destilado alcoólico simples de bagaceira': '500',
#  'Vinho acidificado': '65.000',
#  'Mosto parcialmente fermentado': '-',
#  'Outros derivados': '-',
#  'Total': '318.512.191'}

# %%
# PROCESSAMENTO opcao="opt_03"
scrape_embrapa(ano=2020, opcao="opt_03", subopcao="subopt_01")
# Out:
# {'TINTAS': '28.003.505',
#  'Alicante Bouschet': '2.272.985',
#  'Ancelota': '481.402',
#  'Aramon': '-',
#  'Alfrocheiro': '-',
#  'Arinarnoa': '90.860',
#  'Aspirant Bouschet': '34.513',
#  'Barbera': '12.349',
#  'Bonarda': '-',
#  'Cabernet Franc': '1.506.219',
#  'Cabernet Sauvignon': '5.889.427',
#  'Caladoc': '5.230',
#  'Campanario': '-',
#  'Canaiolo': '-',
#  'Carignan': '-',
#  'Carmenere': '184.268',
#  'Castelão': '-',
#  'Corvina': '2.220',
#  'Croatina': '-',
#  'Cinsaut': '-',
#  'Dom Felder': '-',
#  'Dolcetto': '-',
#  'Durif': '-',
#  'Egiodola': '1.067.591',
#  'Ekigaina': '1.990',
#  'Festival (Sugraone)': '-',
#  'Franconia': '-',
#  'Freisa': '25.330',
#  'Gamay St Romain': '-',
#  'Gamay Beaujolais': '143.278',
#  'Grand Noir': '-',
#  'Grenache': '1.130',
#  'Jaen': '-',
#  'Lagrein': '3.020',
#  'Lambrusco': '29.320',
#  'Malbec': '493.966',
#  'Marzemina': '-',
#  'Merlot': '6.010.486',
#  'Marselan': '449.156',
#  'Mistura de uvas viníferas tinto': '-',
#  'Molinera': '2.198',
#  'Montepulciano': '22.968',
#  'Moscato Bailey': '206.348',
#  'Napa Gamay': '-',
#  'Nebbiolo': '8.642',
#  'Petit Verdot': '228.503',
#  'Petite Sirah': '174.949',
#  'Pinotage': '302.532',
#  'Pinot Noir': '3.588.106',
#  'Pinot Saint George': '-',
#  'Piriquita': '-',
#  'Primitivo': '-',
#  'Rebo': '177.172',
#  'Refosco': '-',
#  'Rondinella': '2.340',
#  'Ruby Cabernet': '218.783',
#  'Sangiovese': '85.292',
#  'Saperavi': '-',
#  'Sira (falsa)': '-',
#  'Tannat': '3.571.972',
#  'Tempranillo': '442.330',
#  'Teroldego': '106.764',
#  'Torrontes': '9.700',
#  'Tinta Barroca': '-',
#  'Tinta Roriz': '-',
#  'Touriga Francesa': '-',
#  'Touriga Nacional': '150.166',
#  'Tinta Madeira': '-',
#  'Tintoria': '-',
#  'Trincdeira': '-',
#  'Trousseau': '-',
#  'Zinfandel': '-',
#  'Outras1': '-',
#  'BRANCAS E ROSADAS': '41.004.206',
#  'Aliatico': '-',
#  'Aligote': '-',
#  'Altesse': '-',
#  'Alvarinho': '46.574',
#  'Arriloba': '2.940',
#  'Auxerrois': '-',
#  'Burger': '-',
#  'Chardonnay': '6.514.864',
#  'Chasselas': '-',
#  'Chenin Blanc': '465.377',
#  'Clairette(1)': '-',
#  'Colombard': '467.614',
#  'Flora': '-',
#  'Garganega': '540',
#  'Gewurztraminer': '192.058',
#  'Gouveio': '-',
#  'Gros Manseng': '6.296',
#  'Italia (Pirovano 65) (PE)': '200',
#  'Maccabeo': '-',
#  'Malvasia': '-',
#  'Malvasia Amarela': '24.440',
#  'Malvasia Bianca': '494.343',
#  'Malvasia Chianti': '-',
#  'Malvasia Verde': '26.597',
#  'Malvasia di Candia': '3.389.071',
#  'Malvasia Istriana': '1.090',
#  'Mistura de uvas viníferas branco': '-',
#  'Mistura de uvas viníferas rosado': '-',
#  'Moscato Branco': '11.868.851',
#  'Moscato Canelli': '138.482',
#  'Moscato Giallo': '1.597.829',
#  'Moscato Nazareno': '554.762',
#  'Moscato Bianco R2': '864.917',
#  'Moscato de Alexandria': '153.442',
#  'Moscato Rosado': '500',
#  'Muscat à Petits Grains': '8.030',
#  'Muller Thurgau': '-',
#  'Muscadelle': '-',
#  'Ora': '-',
#  'Palomino': '-',
#  'Petit Manseng': '-',
#  'Peverella': '15.858',
#  'Pinot Blanc': '3.000',
#  'Pinot Gris': '183.818',
#  'Prosecco': '4.393.451',
#  'Red Veltliner': '-',
#  'Riesling Italico': '3.020.102',
#  'Riesling Renano': '108.260',
#  'Sauvignon Blanc(2)': '818.549',
#  'Sauvignon Gris': '1.028',
#  'Seara Nova': '-',
#  'Semillon': '193.760',
#  'Schonburger': '14.499',
#  'Sylvaner': '-',
#  'Tocai Friulano': '-',
#  'Trebbiano': '4.682.326',
#  'Trebbiano Toscano': '122.512',
#  'Verdea': '-',
#  'Verdelho': '1.540',
#  'Verdiso': '-',
#  'Vermentino': '-',
#  'Vernaccia': '95.680',
#  'Viogner': '-',
#  'Viognier': '531.026',
#  'Outras(3)': '-',
#  'Total': '69.007.711'}

# %%
# COMERCIALIZAÇÃO opcao="opt_04"
scrape_embrapa(ano=2020, opcao="opt_04")
# Out:
# {'VINHO DE MESA': '215.557.931',
#  'Tinto': '-',
#  'Rosado': '-',
#  'Branco': '-',
#  'VINHO FINO DE MESA': '24.310.834',
#  'VINHO FRIZANTE': '2.557.585',
#  'VINHO ORGÂNICO': '10.718',
#  'VINHO ESPECIAL': '-',
#  'ESPUMANTES': '22.610.762',
#  'Espumante  Moscatel': '9.298.571',
#  'Espumante': '13.311.450',
#  'Espumante Orgânico': '742',
#  'SUCO DE UVAS': '144.889.668',
#  'Suco Natural Integral': '114.453.657',
#  'Suco Adoçado': '-',
#  'Suco Reprocessado/reconstituido': '22.066.742',
#  'Suco Orgânico': '553.391',
#  'Outros sucos de uvas': '7.815.879',
#  'SUCO DE UVAS CONCENTRADO': '22.422.414',
#  'OUTROS PRODUTOS COMERCIALIZADOS': '26.547.242',
#  'Outros vinhos (sem informação detalhada)': '192.057',
#  'Agrin (fermentado, acetico misto)': '-',
#  'Aguardente de vinho 50°gl': '866',
#  'Alcool vinico': '6.640',
#  'Bagaceira (graspa)': '7.610',
#  'Base champenoise champanha': '8.772',
#  'Base charmat champanha': '123',
#  'Base espumante moscatel': '23.703',
#  'Bebida de uva': '354.511',
#  'Borra líquida': '22.975',
#  'Borra seca': '146.260',
#  'Brandy (conhaque)': '7.966',
#  'Cooler': '6.260.381',
#  'Coquetel com vinho': '205.664',
#  'Destilado de vinho': '200',
#  'Filtrado doce': '2.415.338',
#  'Jeropiga': '1.267',
#  'Mistelas': '1.201',
#  'Mosto concentrado': '-',
#  'Mosto de uva': '48.044',
#  'Mosto sulfitado': '-',
#  'Nectar de uva': '3.319.597',
#  'Outros produtos': '2.543.754',
#  'Polpa de uva': '1.129.453',
#  'Preparado líquido para refresco': '11.366',
#  'Refrigerante +50% suco': '144.945',
#  'Sangria': '11.017',
#  'Vinagre balsamico': '248.771',
#  'Vinagre duplo': '1.075.579',
#  'Vinagre simples': '6.049.584',
#  'Vinho acetificado': '1.879.227',
#  'Vinho base para espumantes': '-',
#  'Vinho composto': '63.625',
#  'Vinho licoroso': '362.340',
#  'Vinho leve': '396',
#  'Vinho gaseificado': '4.012',
#  'Total': '458.907.154'}

# %%
# IMPORTAÇÃO opcao="opt_05"
scrape_embrapa(ano=2020, opcao="opt_05", subopcao="subopt_01")
# Out:
# {'Africa do Sul': {'Quantidade (Kg)': '627.150', 'Valor (US$)': '1.701.072'},
#  'Alemanha': {'Quantidade (Kg)': '136.992', 'Valor (US$)': '504.168'},
#  'Argélia': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Arábia Saudita': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Argentina': {'Quantidade (Kg)': '22.610.267', 'Valor (US$)': '66.322.932'},
#  'Armênia': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Austrália': {'Quantidade (Kg)': '212.595', 'Valor (US$)': '792.051'},
#  'Áustria': {'Quantidade (Kg)': '6.540', 'Valor (US$)': '52.348'},
#  'Bermudas': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Bélgica': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Bolívia': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Bósnia-Herzegovina': {'Quantidade (Kg)': '1.218', 'Valor (US$)': '902'},
#  'Brasil': {'Quantidade (Kg)': '4.347', 'Valor (US$)': '41.213'},
#  'Bulgária': {'Quantidade (Kg)': '23.110', 'Valor (US$)': '58.319'},
#  'Canada': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Chile': {'Quantidade (Kg)': '72.726.186', 'Valor (US$)': '176.540.499'},
#  'China': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Coreia do Sul, República': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Croácia': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Cuba': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Emirados Árabes Unidos': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Eslovênia': {'Quantidade (Kg)': '11.392', 'Valor (US$)': '39.771'},
#  'Eslováquia': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Espanha': {'Quantidade (Kg)': '7.169.384', 'Valor (US$)': '19.802.061'},
#  'Estados Unidos': {'Quantidade (Kg)': '366.584', 'Valor (US$)': '2.119.234'},
#  'França': {'Quantidade (Kg)': '5.658.139', 'Valor (US$)': '24.894.394'},
#  'Geórgia': {'Quantidade (Kg)': '20.274', 'Valor (US$)': '42.948'},
#  'Geórgia do Sul e Sandwich do Sul, Ilhas': {'Quantidade (Kg)': '-',
#   'Valor (US$)': '-'},
#  'Grécia': {'Quantidade (Kg)': '61.181', 'Valor (US$)': '219.292'},
#  'Hong Kong': {'Quantidade (Kg)': '311', 'Valor (US$)': '2.776'},
#  'Hungria': {'Quantidade (Kg)': '5.254', 'Valor (US$)': '25.250'},
#  'Indonésia': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Irlanda': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Israel': {'Quantidade (Kg)': '38.239', 'Valor (US$)': '224.349'},
#  'Itália': {'Quantidade (Kg)': '9.659.999', 'Valor (US$)': '32.477.890'},
#  'Japão': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Iugoslávia': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Líbano': {'Quantidade (Kg)': '12.384', 'Valor (US$)': '45.908'},
#  'Luxemburgo': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Macedônia': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Marrocos': {'Quantidade (Kg)': '2.160', 'Valor (US$)': '8.326'},
#  'México': {'Quantidade (Kg)': '33', 'Valor (US$)': '181'},
#  'Moldávia': {'Quantidade (Kg)': '5.832', 'Valor (US$)': '8.965'},
#  'Montenegro': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Noruega': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Nova Zelândia': {'Quantidade (Kg)': '15.372', 'Valor (US$)': '89.763'},
#  'Países Baixos (Holanda)': {'Quantidade (Kg)': '2.285',
#   'Valor (US$)': '22.990'},
#  'Panamá': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Paraguai': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Peru': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Porto Rico': {'Quantidade (Kg)': '54', 'Valor (US$)': '1.090'},
#  'Portugal': {'Quantidade (Kg)': '23.627.260', 'Valor (US$)': '66.353.572'},
#  'Reino Unido': {'Quantidade (Kg)': '2.586', 'Valor (US$)': '22.935'},
#  'Republica Dominicana': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Romênia': {'Quantidade (Kg)': '30.635', 'Valor (US$)': '70.269'},
#  'Rússia': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'San Marino': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Sérvia': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Síria': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Suazilândia': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Suíça': {'Quantidade (Kg)': '735', 'Valor (US$)': '5.848'},
#  'Tcheca, República': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Tunísia': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Turquia': {'Quantidade (Kg)': '17.563', 'Valor (US$)': '55.039'},
#  'Ucrânia': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Uruguai': {'Quantidade (Kg)': '4.079.076', 'Valor (US$)': '10.146.829'},
#  'Não consta na tabela': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Não declarados': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Outros': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Total': {'Quantidade (Kg)': '147.135.137', 'Valor (US$)': '402.693.184'}}

# %%
# EXPORTAÇÃO opcao="opt_06"
scrape_embrapa(ano=2020, opcao="opt_06", subopcao="subopt_03")
# Out:
# {'Africa do Sul': {'Quantidade (Kg)': '44', 'Valor (US$)': '152'},
#  'Alemanha, República Democrática': {'Quantidade (Kg)': '1.371.694',
#   'Valor (US$)': '2.791.556'},
#  'Angola': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Antígua e Barbuda': {'Quantidade (Kg)': '304', 'Valor (US$)': '1.013'},
#  'Arabia Saudita': {'Quantidade (Kg)': '32.325', 'Valor (US$)': '95.999'},
#  'Argélia': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Argentina': {'Quantidade (Kg)': '2.002.784', 'Valor (US$)': '3.707.550'},
#  'Áustria': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Bahamas': {'Quantidade (Kg)': '3.208', 'Valor (US$)': '9.449'},
#  'Bahrein': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Bangladesh': {'Quantidade (Kg)': '30', 'Valor (US$)': '214'},
#  'Barbados': {'Quantidade (Kg)': '83', 'Valor (US$)': '197'},
#  'Barein': {'Quantidade (Kg)': '250', 'Valor (US$)': '796'},
#  'Bélgica': {'Quantidade (Kg)': '12.757', 'Valor (US$)': '24.336'},
#  'Belize': {'Quantidade (Kg)': '20', 'Valor (US$)': '32'},
#  'Bermudas': {'Quantidade (Kg)': '390', 'Valor (US$)': '1.375'},
#  'Bolívia': {'Quantidade (Kg)': '92.974', 'Valor (US$)': '34.914'},
#  'Bósnia': {'Quantidade (Kg)': '447', 'Valor (US$)': '472'},
#  'Brasil': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Bulgária': {'Quantidade (Kg)': '100', 'Valor (US$)': '170'},
#  'Burquina Faso': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Cabo Verde': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Camarões': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Camores': {'Quantidade (Kg)': '10', 'Valor (US$)': '34'},
#  'Canadá': {'Quantidade (Kg)': '86.635', 'Valor (US$)': '457.420'},
#  'Catar': {'Quantidade (Kg)': '336', 'Valor (US$)': '432'},
#  'Cayman, Ilhas': {'Quantidade (Kg)': '341', 'Valor (US$)': '1.130'},
#  'Chile': {'Quantidade (Kg)': '266', 'Valor (US$)': '826'},
#  'China': {'Quantidade (Kg)': '1.197', 'Valor (US$)': '3.370'},
#  'Chipre': {'Quantidade (Kg)': '3.407', 'Valor (US$)': '8.717'},
#  'Cingapura': {'Quantidade (Kg)': '6.933', 'Valor (US$)': '29.402'},
#  'Cocos (Keeling), Ilhas': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Cook, Ilhas': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Colômbia': {'Quantidade (Kg)': '15', 'Valor (US$)': '45'},
#  'Congo': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Coreia do Norte': {'Quantidade (Kg)': '30', 'Valor (US$)': '119'},
#  'Coreia do Sul': {'Quantidade (Kg)': '226', 'Valor (US$)': '517'},
#  'Costa do Marfim': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Coveite': {'Quantidade (Kg)': '1.572', 'Valor (US$)': '3.000'},
#  'Croácia': {'Quantidade (Kg)': '16', 'Valor (US$)': '104'},
#  'Curaçao': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Dinamarca': {'Quantidade (Kg)': '62.450', 'Valor (US$)': '135.756'},
#  'Djibuti': {'Quantidade (Kg)': '25', 'Valor (US$)': '41'},
#  'Egito': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Emirados Árabes Unidos': {'Quantidade (Kg)': '220.576',
#   'Valor (US$)': '630.862'},
#  'Eslovênia': {'Quantidade (Kg)': '10', 'Valor (US$)': '29'},
#  'Espanha': {'Quantidade (Kg)': '1.743.131', 'Valor (US$)': '3.842.045'},
#  'Estados Unidos': {'Quantidade (Kg)': '7.879.841',
#   'Valor (US$)': '22.376.155'},
#  'Falkland (Ilhas Malvinas)': {'Quantidade (Kg)': '15', 'Valor (US$)': '100'},
#  'Faroé, Ilhas': {'Quantidade (Kg)': '25', 'Valor (US$)': '98'},
#  'Filipinas': {'Quantidade (Kg)': '441', 'Valor (US$)': '1.135'},
#  'Finlândia': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'França': {'Quantidade (Kg)': '1.419', 'Valor (US$)': '11.552'},
#  'Gabão': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Gana': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Georgia': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Gibraltar': {'Quantidade (Kg)': '243', 'Valor (US$)': '709'},
#  'Grécia': {'Quantidade (Kg)': '2.802', 'Valor (US$)': '6.767'},
#  'Guadalupe': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Guiana': {'Quantidade (Kg)': '1.432', 'Valor (US$)': '3.754'},
#  'Guiana Francesa': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Guiné-Bissau': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Guine Equatorial': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Honduras': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Hong Kong': {'Quantidade (Kg)': '19.362', 'Valor (US$)': '198.977'},
#  'Ilha de Man': {'Quantidade (Kg)': '136', 'Valor (US$)': '411'},
#  'Ilhas Virgens': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Índia': {'Quantidade (Kg)': '502', 'Valor (US$)': '1.167'},
#  'Indonésia': {'Quantidade (Kg)': '13', 'Valor (US$)': '40'},
#  'Irã': {'Quantidade (Kg)': '218', 'Valor (US$)': '531'},
#  'Iraque': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Irlanda': {'Quantidade (Kg)': '805.090', 'Valor (US$)': '1.768.519'},
#  'Islândia': {'Quantidade (Kg)': '40', 'Valor (US$)': '61'},
#  'Itália': {'Quantidade (Kg)': '118', 'Valor (US$)': '301'},
#  'Japão': {'Quantidade (Kg)': '779', 'Valor (US$)': '2.157'},
#  'Jérsei': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Jordânia': {'Quantidade (Kg)': '31', 'Valor (US$)': '75'},
#  'Letônia': {'Quantidade (Kg)': '40', 'Valor (US$)': '102'},
#  'Líbano': {'Quantidade (Kg)': '33', 'Valor (US$)': '119'},
#  'Libéria': {'Quantidade (Kg)': '10.238', 'Valor (US$)': '30.285'},
#  'Líbia': {'Quantidade (Kg)': '20', 'Valor (US$)': '55'},
#  'Lituânia': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Luxemburgo': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Macedônia': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Malásia': {'Quantidade (Kg)': '2.065', 'Valor (US$)': '30.729'},
#  'Malta': {'Quantidade (Kg)': '4.282', 'Valor (US$)': '11.606'},
#  'Marianas do Norte, Ilhas': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Marrocos': {'Quantidade (Kg)': '8', 'Valor (US$)': '22'},
#  'Marshall, Ilhas': {'Quantidade (Kg)': '13.769', 'Valor (US$)': '41.407'},
#  'Martinica': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Mauricio': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Mauritânia': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Mexico': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Mônaco': {'Quantidade (Kg)': '20', 'Valor (US$)': '59'},
#  'Mongólia': {'Quantidade (Kg)': '10', 'Valor (US$)': '15'},
#  'Montenegro': {'Quantidade (Kg)': '40', 'Valor (US$)': '147'},
#  'Nigéria': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Noruega': {'Quantidade (Kg)': '183.232', 'Valor (US$)': '572.588'},
#  'Omã': {'Quantidade (Kg)': '43', 'Valor (US$)': '234'},
#  'Países Baixos': {'Quantidade (Kg)': '20.360.309',
#   'Valor (US$)': '40.052.845'},
#  'Palau': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Panamá': {'Quantidade (Kg)': '10.170', 'Valor (US$)': '25.834'},
#  'Paquistão': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Paraguai': {'Quantidade (Kg)': '3.750', 'Valor (US$)': '2.881'},
#  'Pitcairn': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Polônia': {'Quantidade (Kg)': '4', 'Valor (US$)': '7'},
#  'Porto Rico': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Portugal': {'Quantidade (Kg)': '15.803', 'Valor (US$)': '26.426'},
#  'Quirguistão': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Reino Unido': {'Quantidade (Kg)': '13.978.476', 'Valor (US$)': '31.486.021'},
#  'Republica Dominicana': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Romênia': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Rússia,  Federação da': {'Quantidade (Kg)': '216.906',
#   'Valor (US$)': '472.154'},
#  'Samoa Americana': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'São Cristóvão e Névis': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'São Tomé e Príncipe': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'São Vicente e Granadinas': {'Quantidade (Kg)': '20', 'Valor (US$)': '69'},
#  'Serra Leoa': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Senegal': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Singapura': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Sri Lanka': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Suazilândia': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Suécia': {'Quantidade (Kg)': '50', 'Valor (US$)': '163'},
#  'Suíça': {'Quantidade (Kg)': '2.209', 'Valor (US$)': '20.998'},
#  'Suriname': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Tailândia': {'Quantidade (Kg)': '762', 'Valor (US$)': '3.001'},
#  'Taiwan': {'Quantidade (Kg)': '90', 'Valor (US$)': '242'},
#  'Tanzânia': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Togo': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Trindade e Tobago': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Tunísia': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Turcas e Caicos, ilhas': {'Quantidade (Kg)': '18', 'Valor (US$)': '51'},
#  'Turquia': {'Quantidade (Kg)': '353', 'Valor (US$)': '868'},
#  'Tuvalu': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Uruguai': {'Quantidade (Kg)': '68.196', 'Valor (US$)': '58.419'},
#  'Vanuatu': {'Quantidade (Kg)': '26', 'Valor (US$)': '73'},
#  'Venezuela': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Vietnã': {'Quantidade (Kg)': '18', 'Valor (US$)': '49'},
#  'Wallis e Futuna, Ilhas': {'Quantidade (Kg)': '-', 'Valor (US$)': '-'},
#  'Provisão de Navios e Aeronaves': {'Quantidade (Kg)': '-',
#   'Valor (US$)': '-'},
#  'Total': {'Quantidade (Kg)': '49.228.053', 'Valor (US$)': '108.992.052'}}

# %%
from fastapi import FastAPI, Depends, HTTPException
from fastapi.security import HTTPBearer

# %%
app = FastAPI()
security = HTTPBearer()

# --- Autenticação (Opcional) ---
@app.post("/login")
def login(username: str, password: str):
    # Lógica JWT (exemplo simplificado)
    return {"token": "TOKEN_JWT_AQUI"}

# --- Endpoints Principais ---
@app.get("/producao/{ano}")
def get_producao(ano: int):
    return scrape_embrapa(ano, "opt_02")

@app.get("/processamento/{tipo}/{ano}")
def get_processamento(tipo: str, ano: int):
    subopcoes = tipo
    return scrape_embrapa(ano, "opt_03", subopcoes)

@app.get("/comercializacao/{ano}")
def get_comercializacao(ano: int):
    return scrape_embrapa(ano, "opt_04")

@app.get("/importacao/{produto}/{ano}")
def get_importacao(produto: str, ano: int):
    subopcoes = produto
    return scrape_embrapa(ano, "opt_05", subopcoes)

@app.get("/exportacao/{produto}/{ano}")
def get_exportacao(produto: str, ano: int):
    subopcoes = produto
    return scrape_embrapa(ano, "opt_06", subopcoes)
